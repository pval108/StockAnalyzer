# %%
import yfinance as yf
import pandas as pd
import numpy as np
import plotly.graph_objects as go
pd.set_option('display.max_rows', None)
pd.set_option('display.float_format', lambda x: '%.3f' % x)
from pandas_datareader import data as pdr
pd.options.display.float_format = '{:,}'.format
import datetime as dt
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

# %%
t = yf.Ticker('cvx')

# %%
df = pd.DataFrame.from_dict(t.info.items())
df = df.rename(columns={0: "Financials", 1: "Fundamentals"})
#np.array(df['Financials'])

# %%
df1 = df[df['Financials'].isin([
    'longName',
    'symbol',
    'profitMargins',
    'grossMargins',
    'operatingMargins',
     'returnOnEquity',
    'returnOnAssets',
    'priceToSalesTrailing12Months',
    'pegRatio',
    'priceToBook',
    'trailingEps',
    'trailingPE',
    'revenuePerShare',
    'totalCashPerShare',
    'earningsGrowth',
    'revenueGrowth',
     'fiftyTwoWeekHigh',
    'fiftyTwoWeekLow',
    'targetHighPrice',
     'currentPrice',
    'threeYearAverageReturn',
    'fiveYearAverageReturn',
    'fiftyDayAverage',
    'currentPrice',
    'ytdReturn'
    'currentRatio',
    'totalCash',
    'totalDebt',
    'quickRatio',
    'marketCap',
    'dividendYield',
    'enterpriseValue',
    'enterpriseToEbitda',
    'ebitda','totalCashPerShare'
    ])]

# %%
t.major_holders
# Out:
#         0                                      1
# 0   0.03%        % of Shares Held by All Insider
# 1  67.73%       % of Shares Held by Institutions
# 2  67.76%        % of Float Held by Institutions
# 3    3098  Number of Institutions Holding Shares

# %% [markdown]
# # Balance Sheet

# %%
d=t.balance_sheet.reset_index()
d = d[d['index'].isin(['Total Liab','Total Assets','Total Stockholder Equity'])]
d= d.iloc[:,:2]
d.columns = ['Financials','Fundamentals']
df1 = pd.concat([df1,d]).reset_index(drop=True)

# %%
f=t.balance_sheet.reset_index()
f = f[f['index'].isin(['Total Liab','Total Assets','Total Stockholder Equity'])]
f = f.set_index('index')
f = f/1000000
fp = round((f.pct_change(axis=1,periods=-1)*100),2).rename(index={'Total Liab': 'Total Liab pct_chg',
                                                                 'Total Stockholder Equity': 'Total Stockholder Equity pct_chg',
                                                                 'Total Assets': 'Total Assets pct_chg'})
round(f.append(fp).sort_index().astype('float'),2)
# Out:
#                                   2020-12-31 00:00:00  2019-12-31 00:00:00  \
# index
# Total Assets                                239,790.0            237,428.0
# Total Assets pct_chg                             0.99                -6.47
# Total Liab                                  107,064.0             92,220.0
# Total Liab pct_chg                               16.1                -6.11
# Total Stockholder Equity                    131,688.0            144,213.0
# Total Stockholder Equity pct_chg                -8.69                -6.69
#
#                                   2018-12-31 00:00:00  2017-12-31 00:00:00
# index
# Total Assets                                253,863.0            253,806.0
# Total Assets pct_chg                             0.02                  NaN
# Total Liab                                   98,221.0            104,487.0
# Total Liab pct_chg                               -6.0                  NaN
# Total Stockholder Equity                    154,554.0            148,124.0
# Total Stockholder Equity pct_chg                 4.34                  NaN

# %%
bs = t.get_balancesheet()/1000000

# %%
#quick Ration
qr=round((t.get_balancesheet().filter(items = ['Total Current Assets'], axis=0).values-t.get_balancesheet().filter(items = ['Inventory'], axis=0).values)/t.get_balancesheet().filter(items = ['Total Current Liabilities'], axis=0)*100,2)
qr = qr.rename(index={'Total Current Liabilities': 'Quick Ratio'})
bs = bs.append(qr)

# %% [markdown]
# # Earnings

# %%
e = t.earnings/1000000
e2 = round((e.pct_change(axis=0,)*100),2)
pd.merge(e,e2,left_index=True,right_index=True).rename(columns={'Revenue_y': 'Revenue %','Earnings_y': 'Earnings %','Revenue_x': 'Revenue','Earnings_x': 'Earnings'})
# Out:
#        Revenue  Earnings  Revenue %  Earnings %
# Year
# 2017 127,485.0   9,195.0        NaN         NaN
# 2018 158,902.0  14,824.0      24.64       61.22
# 2019 139,865.0   2,924.0     -11.98      -80.28
# 2020  94,471.0  -5,543.0     -32.46     -289.57

# %%
eq = t.quarterly_earnings/1000000
eq2 = round((eq.pct_change(axis=0,)*100),2)
eq2 = pd.merge(eq,eq2,left_index=True,right_index=True).rename(columns={'Revenue_y': 'Revenue %','Earnings_y': 'Earnings %','Revenue_x': 'Revenue','Earnings_x': 'Earnings'})
eq2
# Out:
#          Revenue  Earnings  Revenue %  Earnings %
# Quarter
# 3Q2020  23,997.0    -207.0        NaN         NaN
# 4Q2020  24,843.0    -665.0       3.53      221.26
# 1Q2021  31,076.0   1,377.0      25.09     -307.07
# 2Q2021  36,117.0   3,082.0      16.22      123.82

# %%
fin =t.financials/1000000
fin2= fin
fin2['avg']=fin2.sum(axis=1)/4
fin2
# Out:
#                                        2020-12-31 00:00:00  \
# Research Development                                   NaN
# Effect Of Accounting Charges                           NaN
# Income Before Tax                                 -7,453.0
# Minority Interest                                  1,038.0
# Net Income                                        -5,543.0
# Selling General Administrative                    24,557.0
# Gross Profit                                      43,983.0
# Ebit                                              -3,319.0
# Operating Income                                  -3,319.0
# Other Operating Expenses                           4,492.0
# Interest Expense                                    -697.0
# Extraordinary Items                                    NaN
# Non Recurring                                          NaN
# Other Items                                            NaN
# Income Tax Expense                                -1,892.0
# Total Revenue                                     94,471.0
# Total Operating Expenses                          97,790.0
# Cost Of Revenue                                   50,488.0
# Total Other Income Expense Net                    -4,134.0
# Discontinued Operations                                NaN
# Net Income From Continuing Ops                    -5,561.0
# Net Income Applicable To Common Shares            -5,543.0
#
#                                        2019-12-31 00:00:00  \
# Research Development                                   NaN
# Effect Of Accounting Charges                           NaN
# Income Before Tax                                  5,536.0
# Minority Interest                                    995.0
# Net Income                                         2,924.0
# Selling General Administrative                    25,945.0
# Gross Profit                                      59,752.0
# Ebit                                              10,478.0
# Operating Income                                  10,478.0
# Other Operating Expenses                           4,138.0
# Interest Expense                                    -798.0
# Extraordinary Items                                    NaN
# Non Recurring                                          NaN
# Other Items                                            NaN
# Income Tax Expense                                 2,691.0
# Total Revenue                                    139,865.0
# Total Operating Expenses                         129,387.0
# Cost Of Revenue                                   80,113.0
# Total Other Income Expense Net                    -4,942.0
# Discontinued Operations                                NaN
# Net Income From Continuing Ops                     2,845.0
# Net Income Applicable To Common Shares             2,924.0
#
#                                        2018-12-31 00:00:00  \
# Research Development                                   NaN
# Effect Of Accounting Charges                           NaN
# Income Before Tax                                 20,575.0
# Minority Interest                                  1,088.0
# Net Income                                        14,824.0
# Selling General Administrative                    24,942.0
# Gross Profit                                      64,324.0
# Ebit                                              14,624.0
# Operating Income                                  14,624.0
# Other Operating Expenses                           4,864.0
# Interest Expense                                    -748.0
# Extraordinary Items                                    NaN
# Non Recurring                                          NaN
# Other Items                                            NaN
# Income Tax Expense                                 5,715.0
# Total Revenue                                    158,902.0
# Total Operating Expenses                         144,278.0
# Cost Of Revenue                                   94,578.0
# Total Other Income Expense Net                     5,951.0
# Discontinued Operations                                NaN
# Net Income From Continuing Ops                    14,860.0
# Net Income Applicable To Common Shares            14,824.0
#
#                                        2017-12-31 00:00:00        avg
# Research Development                                   NaN        0.0
# Effect Of Accounting Charges                           NaN        0.0
# Income Before Tax                                  9,221.0   6,969.75
# Minority Interest                                  1,195.0    1,079.0
# Net Income                                         9,195.0    5,350.0
# Selling General Administrative                    23,885.0  24,832.25
# Gross Profit                                      58,909.0   56,742.0
# Ebit                                               3,499.0    6,320.5
# Operating Income                                   3,499.0    6,320.5
# Other Operating Expenses                          12,333.0   6,456.75
# Interest Expense                                    -307.0     -637.5
# Extraordinary Items                                    NaN        0.0
# Non Recurring                                          NaN        0.0
# Other Items                                            NaN        0.0
# Income Tax Expense                                   -48.0    1,616.5
# Total Revenue                                    127,485.0 130,180.75
# Total Operating Expenses                         123,986.0 123,860.25
# Cost Of Revenue                                   68,576.0  73,438.75
# Total Other Income Expense Net                     5,722.0     649.25
# Discontinued Operations                                NaN        0.0
# Net Income From Continuing Ops                     9,269.0   5,353.25
# Net Income Applicable To Common Shares             9,195.0    5,350.0

# %%
round((fin2.pct_change(axis=1,periods=-1)*100),2).filter(items = ['Gross Profit','Net Income',
                                                                                   'Total Revenue','Operating Income',
                                                                                   'Research Development'], axis=0)
# Out:
#                       2020-12-31 00:00:00  2019-12-31 00:00:00  \
# Gross Profit                       -26.39                -7.11
# Net Income                        -289.57               -80.28
# Total Revenue                      -32.46               -11.98
# Operating Income                  -131.68               -28.35
# Research Development                  NaN                  NaN
#
#                       2018-12-31 00:00:00  2017-12-31 00:00:00  avg
# Gross Profit                         9.19                 3.82  NaN
# Net Income                          61.22                71.87  NaN
# Total Revenue                       24.64                -2.07  NaN
# Operating Income                   317.95               -44.64  NaN
# Research Development                  NaN                  NaN  NaN

# %%
t.quarterly_financials/1000000
# Out:
#                                        2021-06-30 2021-03-31 2020-12-31  \
# Research Development                          NaN        NaN        NaN
# Effect Of Accounting Charges                  NaN        NaN        NaN
# Income Before Tax                         4,422.0    2,177.0     -957.0
# Minority Interest                           729.0    1,045.0    1,038.0
# Net Income                                3,082.0    1,377.0     -665.0
# Selling General Administrative            6,160.0    6,294.0    5,629.0
# Gross Profit                             15,488.0   13,508.0   11,456.0
# Ebit                                      3,131.0    1,383.0    2,494.0
# Operating Income                          3,131.0    1,383.0    2,494.0
# Other Operating Expenses                  1,562.0    1,459.0    1,272.0
# Interest Expense                           -185.0     -198.0     -199.0
# Extraordinary Items                           NaN        NaN        NaN
# Non Recurring                                 NaN        NaN        NaN
# Other Items                                   NaN        NaN        NaN
# Income Tax Expense                        1,328.0      779.0     -301.0
# Total Revenue                            36,117.0   31,076.0   24,843.0
# Total Operating Expenses                 32,986.0   29,693.0   22,349.0
# Cost Of Revenue                          20,629.0   17,568.0   13,387.0
# Total Other Income Expense Net            1,291.0      794.0   -3,451.0
# Discontinued Operations                       NaN        NaN        NaN
# Net Income From Continuing Ops            3,094.0    1,398.0     -656.0
# Net Income Applicable To Common Shares    3,082.0    1,377.0     -665.0
#
#                                        2020-09-30
# Research Development                          NaN
# Effect Of Accounting Charges                  NaN
# Income Before Tax                           -44.0
# Minority Interest                           264.0
# Net Income                                 -207.0
# Selling General Administrative            5,658.0
# Gross Profit                             10,549.0
# Ebit                                       -328.0
# Operating Income                           -328.0
# Other Operating Expenses                  1,085.0
# Interest Expense                           -164.0
# Extraordinary Items                           NaN
# Non Recurring                                 NaN
# Other Items                                   NaN
# Income Tax Expense                          165.0
# Total Revenue                            23,997.0
# Total Operating Expenses                 24,325.0
# Cost Of Revenue                          13,448.0
# Total Other Income Expense Net              284.0
# Discontinued Operations                       NaN
# Net Income From Continuing Ops             -209.0
# Net Income Applicable To Common Shares     -207.0

# %%
round((t.quarterly_financials.pct_change(axis=1,periods=-1)*100),2).filter(items = ['Gross Profit','Net Income',
                                                                                   'Total Revenue','Operating Income',
                                                                                   'Research Development'], axis=0)
# Out:
#                       2021-06-30  2021-03-31  2020-12-31  2020-09-30
# Gross Profit               14.66       17.91         8.6         NaN
# Net Income                123.82     -307.07      221.26         NaN
# Total Revenue              16.22       25.09        3.53         NaN
# Operating Income          126.39      -44.55     -860.37         NaN
# Research Development         NaN         NaN         NaN         NaN

# %% [markdown]
# # Cash Flow

# %%
cf = t.cashflow
cf2 = cf.filter(items = ['Total Cash From Operating Activities'], axis=0).values+cf.filter(items = ['Capital Expenditures'], axis=0)
cf2 = cf2.rename(index={'Capital Expenditures': 'Free Cash Flow'})
cf2 = cf.append(cf2)/1000000
cf3 = cf2
cf3['avg']=cf3.sum(axis=1)/4
cf3
# Out:
#                                            2020-12-31 00:00:00  \
# Investments                                              112.0
# Change To Liabilities                                 -3,576.0
# Total Cashflows From Investing Activities             -6,965.0
# Net Borrowings                                         7,470.0
# Total Cash From Financing Activities                  -3,736.0
# Change To Operating Activities                           -39.0
# Net Income                                            -5,543.0
# Change In Cash                                          -174.0
# Repurchase Of Stock                                   -1,531.0
# Effect Of Exchange Rate                                  -50.0
# Total Cash From Operating Activities                  10,577.0
# Depreciation                                          17,383.0
# Other Cashflows From Investing Activities             -1,419.0
# Dividends Paid                                        -9,651.0
# Change To Inventory                                      284.0
# Change To Account Receivables                          2,423.0
# Other Cashflows From Financing Activities                -24.0
# Change To Netincome                                      341.0
# Capital Expenditures                                  -8,922.0
# Issuance Of Stock                                          NaN
# Free Cash Flow                                         1,655.0
#
#                                            2019-12-31 00:00:00  \
# Investments                                            1,094.0
# Change To Liabilities                                   -109.0
# Total Cashflows From Investing Activities            -11,458.0
# Net Borrowings                                        -7,846.0
# Total Cash From Financing Activities                 -19,758.0
# Change To Operating Activities                           110.0
# Net Income                                             2,924.0
# Change In Cash                                        -3,570.0
# Repurchase Of Stock                                   -2,935.0
# Effect Of Exchange Rate                                  332.0
# Total Cash From Operating Activities                  27,314.0
# Depreciation                                          18,546.0
# Other Cashflows From Investing Activities             -1,245.0
# Dividends Paid                                        -8,959.0
# Change To Inventory                                        7.0
# Change To Account Receivables                          1,852.0
# Other Cashflows From Financing Activities                -18.0
# Change To Netincome                                    3,917.0
# Capital Expenditures                                 -14,116.0
# Issuance Of Stock                                          NaN
# Free Cash Flow                                        13,198.0
#
#                                            2018-12-31 00:00:00  \
# Investments                                             -609.0
# Change To Liabilities                                   -494.0
# Total Cashflows From Investing Activities            -12,290.0
# Net Borrowings                                        -4,502.0
# Total Cash From Financing Activities                 -13,699.0
# Change To Operating Activities                           269.0
# Net Income                                            14,824.0
# Change In Cash                                         4,538.0
# Repurchase Of Stock                                     -604.0
# Effect Of Exchange Rate                                  -91.0
# Total Cash From Operating Activities                  30,618.0
# Depreciation                                          19,017.0
# Other Cashflows From Investing Activities                111.0
# Dividends Paid                                        -8,502.0
# Change To Inventory                                     -424.0
# Change To Account Receivables                            437.0
# Other Cashflows From Financing Activities                -91.0
# Change To Netincome                                   -2,923.0
# Capital Expenditures                                 -13,792.0
# Issuance Of Stock                                          NaN
# Free Cash Flow                                        16,826.0
#
#                                            2017-12-31 00:00:00        avg
# Investments                                              170.0     191.75
# Change To Liabilities                                    998.0    -795.25
# Total Cashflows From Investing Activities             -8,320.0  -9,758.25
# Net Borrowings                                        -7,461.0  -3,084.75
# Total Cash From Financing Activities                 -14,554.0 -12,936.75
# Change To Operating Activities                          -449.0     -27.25
# Net Income                                             9,195.0    5,350.0
# Change In Cash                                        -2,471.0    -419.25
# Repurchase Of Stock                                     -604.0   -1,418.5
# Effect Of Exchange Rate                                   65.0       64.0
# Total Cash From Operating Activities                  20,338.0  22,211.75
# Depreciation                                          18,367.0  18,328.25
# Other Cashflows From Investing Activities                -16.0    -642.25
# Dividends Paid                                        -8,132.0   -8,811.0
# Change To Inventory                                     -267.0     -100.0
# Change To Account Receivables                           -915.0     949.25
# Other Cashflows From Financing Activities                -78.0     -52.75
# Change To Netincome                                   -7,122.0  -1,446.75
# Capital Expenditures                                 -13,404.0  -12,558.5
# Issuance Of Stock                                      1,117.0     279.25
# Free Cash Flow                                         6,934.0   9,653.25

# %%
round((cf3.pct_change(axis=1,periods=-1)*100),2).filter(items = ['Free Cash Flow'], axis=0).iloc[:,:-1]
# Out:
#                 2020-12-31 00:00:00  2019-12-31 00:00:00  2018-12-31 00:00:00  \
# Free Cash Flow               -87.46               -21.56               142.66
#
#                 2017-12-31 00:00:00
# Free Cash Flow               -28.17

# %%
cfq = t.quarterly_cashflow
cfq2 = cfq.filter(items = ['Total Cash From Operating Activities'], axis=0).values+cfq.filter(items = ['Capital Expenditures'], axis=0)
cfq2 = cfq2.rename(index={'Capital Expenditures': 'Free Cash Flow'})
cfq2 = cfq.append(cfq2)/1000000
cfq2
# Out:
#                                            2021-06-30  2021-03-31  2020-12-31  \
# Investments                                       6.0        11.0        10.0
# Change To Liabilities                         2,152.0     1,599.0        33.0
# Total Cashflows From Investing Activities    -1,572.0    -1,563.0      -690.0
# Net Borrowings                               -2,463.0     1,159.0      -220.0
# Total Cash From Financing Activities         -4,945.0    -1,053.0    -2,685.0
# Change To Operating Activities                   23.0      -118.0      -610.0
# Issuance Of Stock                               106.0       267.0        14.0
# Net Income                                    3,082.0     1,377.0      -665.0
# Change In Cash                                  424.0     1,527.0    -1,054.0
# Effect Of Exchange Rate                         -13.0       -53.0        83.0
# Total Cash From Operating Activities          6,954.0     4,196.0     2,238.0
# Depreciation                                  4,522.0     4,286.0     2,361.0
# Other Cashflows From Investing Activities        14.0        25.0        15.0
# Dividends Paid                               -2,573.0    -2,468.0    -2,465.0
# Change To Inventory                            -522.0        51.0        83.0
# Change To Account Receivables                -1,898.0    -2,827.0    -1,178.0
# Other Cashflows From Financing Activities       -15.0       -11.0       -14.0
# Change To Netincome                            -442.0      -549.0     2,064.0
# Capital Expenditures                         -1,797.0    -1,746.0    -2,067.0
# Free Cash Flow                                5,157.0     2,450.0       171.0
#
#                                            2020-09-30
# Investments                                      72.0
# Change To Liabilities                         1,203.0
# Total Cashflows From Investing Activities    -1,827.0
# Net Borrowings                                  689.0
# Total Cash From Financing Activities         -1,696.0
# Change To Operating Activities                  239.0
# Issuance Of Stock                                 5.0
# Net Income                                     -207.0
# Change In Cash                                   12.0
# Effect Of Exchange Rate                          -2.0
# Total Cash From Operating Activities          3,537.0
# Depreciation                                  4,017.0
# Other Cashflows From Investing Activities      -360.0
# Dividends Paid                               -2,390.0
# Change To Inventory                            -170.0
# Change To Account Receivables                -1,168.0
# Other Cashflows From Financing Activities       -14.0
# Change To Netincome                            -624.0
# Capital Expenditures                         -1,630.0
# Free Cash Flow                                1,907.0

# %%
round((cfq2.pct_change(axis=1,periods=-1)*100),2).filter(items = ['Free Cash Flow'], axis=0)
# Out:
#                 2021-06-30  2021-03-31  2020-12-31  2020-09-30
# Free Cash Flow      110.49    1,332.75      -91.03         NaN

# %% [markdown]
# # Debt

# %%
df1 = df1.set_index('Financials')

# %%
dt = df1.filter(items = ['totalDebt'], axis=0).values/df1.filter(items = ['Total Stockholder Equity','Total Assets'], axis=0)
dt = dt.rename(index={'Total Stockholder Equity': 'Debt to Equity',
                     'Total Assets': 'Debt to Assets'})

# %%
fcfy = (cf2.iloc[:,:1].filter(items = ['Free Cash Flow'], axis=0).values*1000000/df1.filter(items = ['enterpriseValue'], axis=0))*100
fcfy = fcfy.rename(index={'enterpriseValue': 'FCF Yield-EV'})

# %%
fcfy2 = (cf2.iloc[:,:1].filter(items = ['Free Cash Flow'], axis=0).values*1000000/df1.filter(items = ['marketCap'], axis=0))*100
fcfy2 = fcfy2.rename(index={'marketCap': 'FCF Yield-MarketCap'})

# %%
df1 = df1.append([dt,fcfy,fcfy2])

# %%
fi= round(int(df1.filter(items = ['totalDebt'], axis=0).reset_index(drop=True).values[0])/(f.filter(items = [
    'Total Stockholder Equity'
    ,'Total Assets'], axis=0).rename(index={'Total Stockholder Equity': 'Debt to Equity',
'Total Assets': 'Debt to Assets'})*1000000),2)

# %%
bs.iloc[[-1]].append(fi)
# Out:
#                 2020-12-31  2019-12-31  2018-12-31  2017-12-31
# Quick Ratio          91.97       84.74      104.22       82.83
# Debt to Equity        0.33         0.3        0.28        0.29
# Debt to Assets        0.18        0.18        0.17        0.17

# %% [markdown]
# # Profitabilility

# %%
round(df1.filter(items = ['profitMargins','grossMargins','operatingMargins','revenueGrowth','earningsGrowth','returnOnAssets','returnOnEquity'], axis=0).astype('float')*100,2).rename(index={
    'profitMargins': 'Profit Margin',
                                                      'grossMargins': 'Gross Margin',
                                                      'operatingMargins': 'Operating Margin',
                                                      'revenueGrowth': 'Revenue Growth',
                                                      'earningsGrowth': 'Earnings Growth',
                                                         'returnOnAssets': 'Return on Assets',
                                                         'returnOnEquity': 'Return on Equity'})
# Out:
#                   Fundamentals
# Financials
# Profit Margin             3.09
# Gross Margin             43.95
# Operating Margin          5.76
# Revenue Growth           126.8
# Earnings Growth            NaN
# Return on Assets          1.79
# Return on Equity           2.7

# %% [markdown]
# # Valuation

# %%
v1 = round(df1.filter(items = ['priceToBook','trailingPE','pegRatio','trailingEps','priceToSalesTrailing12Months','totalCashPerShare','revenuePerShare'], axis=0),2)

# %%
ptcf=df1.filter(items = ['currentPrice'], axis=0).values/df1.filter(items = ['totalCashPerShare'], axis=0)
ptcf = ptcf.rename(index={'totalCashPerShare': 'Price to Cash Flow'})
ptcf= round(ptcf,2)
round(v1.append(ptcf).astype('float'),2).rename(index={'priceToBook': 'Price/Book',
                                                      'trailingPE': 'Price/Earnings',
                                                      'pegRatio': 'Price/Earnings-to-Growth',
                                                      'priceToSalesTrailing12Months': 'Price/Sales',
                                                      'trailingEps': 'Earnings Per Share',
                                                      'totalCashPerShare': 'Total Cash Per Share',
                                                      'revenuePerShare': 'Revenue Per Share'})
# Out:
#                           Fundamentals
# Financials
# Price/Book                        1.66
# Price/Earnings                   60.56
# Price/Earnings-to-Growth          -3.2
# Earnings Per Share                1.88
# Price/Sales                        1.9
# Total Cash Per Share              3.91
# Revenue Per Share                61.11
# Price to Cash Flow               29.18

# %% [markdown]
# # Trendline

# %%
from datetime import datetime
import plotly.graph_objects as go

# %%
wt = t.history()#.#datetime.now()
#wt.filter(like = -1, axis=0)
wt =wt.reset_index(drop=False).iloc[-1]['Date']

# %%
date_format = '%Y-%m-%d'
dtObj = datetime.strptime(str(wt)[0:10], date_format)
n = 36
past_date = dtObj - pd.DateOffset(months=n)

# %%
tt = t.history(start=past_date,  end=wt).reset_index()

# %%
fig = go.Figure(data=[go.Candlestick(x=tt['Date'],
                                   open=tt['Open'],
                                     high=tt['High'],
                                     low=tt['Low'],
                                     close=tt['Close'])])

fig.update_layout(
    title= str(t).replace('yfinance.Ticker object <','').replace('>','') + ' ' +str(t.info['currentPrice']),
   font=dict(
        family="Courier New, monospace",
        size=16,
        color="#7f7f7f"))

fig.update_layout(
    autosize=False,
    width=1000,
    height=600,)

fig.show()

# %%
delta = tt['Close'].diff()
up = delta.clip(lower=0)
down = -1*delta.clip(upper=0)
ema_up = up.ewm(com=13, adjust=False).mean()
ema_down = down.ewm(com=13, adjust=False).mean()
rs = ema_up/ema_down

tt['RSI'] = 100 - (100/(1 + rs))

# Skip first 14 days to have real values
ticker = tt.iloc[14:]

# %% [markdown]
# # RSI

# %%
print(f"RSI: {ticker.iloc[-1,-1].round(2)}") 

fig, (ax1, ax2) = plt.subplots(2)
ax1.get_xaxis().set_visible(False)
fig.suptitle('Stock')

ticker['Close'].plot(ax=ax1)
ax1.set_ylabel('Price ($)')
ticker['RSI'].plot(ax=ax2)
ax2.set_ylim(0,100)
ax2.axhline(30, color='r', linestyle='--')
ax2.axhline(70, color='r', linestyle='--')
ax2.set_ylabel('RSI')
fig.set_size_inches(15, 7)
plt.subplots_adjust(left=0.11, bottom=0.24, right=0.87, top=0.90, wspace=0.2, hspace=0)
plt.show()
# Out:
# RSI: 74.33
